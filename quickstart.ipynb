# %% [markdown]
# Test 1 - 5/22 Night:
# - Inital Scrape via API works but content for email isn't showing
# - Trying nltk, spacy and beautifulsoup for word processing to see if I can get more accurate scraping -> 2nd rendition doesn't process as many emails as inital scrape

# %%
#!pip install python-dotenv pandas openpyxl nltk spacy
#!pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
import os.path
import base64
import json
import re
import pandas as pd
import nltk
import spacy

from bs4 import BeautifulSoup
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %%
# initializing spaCy
nlp = spacy.load('en_core_web_sm')

# %%
SCOPES = [
    'https://www.googleapis.com/auth/gmail.readonly',
    'https://www.googleapis.com/auth/userinfo.email',
    'https://www.googleapis.com/auth/gmail.addons.current.action.compose',
    'https://www.googleapis.com/auth/gmail.addons.current.message.action',
    'openid'
]


def main():
    """Shows basic usage of the Gmail API.
    Lists the user's Gmail labels and processes messages.
    """
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
        print("Loaded credentials from token.json")
    else:
        print("token.json not found, need to authenticate")
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            try:
                creds.refresh(Request())
                print("Credentials refreshed")
            except Exception as e:
                print(f"Failed to refresh credentials: {e}")
        else:
            try:
                flow = InstalledAppFlow.from_client_secrets_file(
                    'credentials.json', SCOPES)
                creds = flow.run_local_server(port=0)
                print("Credentials obtained from flow")
            except Exception as e:
                print(f"Failed to obtain credentials: {e}")
                return
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())
            print("Credentials saved to token.json")

    try:
        # Call the Gmail API
        service = build('gmail', 'v1', credentials=creds)

        # Get list of messages from the last 5 months
        results = service.users().messages().list(userId='me', q='newer_than:150d').execute()
        messages = results.get('messages', [])

        job_data = []

        if not messages:
            print('No messages found.')
        else:
            print('Messages:')
            for message in messages:
                msg = service.users().messages().get(userId='me', id=message['id']).execute()
                payload = msg['payload']
                headers = payload.get('headers')
                for header in headers:
                    if header['name'] == 'Subject':
                        subject = header['value']
                    if header['name'] == 'From':
                        from_ = header['value']
                    if header['name'] == 'Date':
                        date_ = header['value']
                job_data.append({
                    "Subject": subject,
                    "From": from_,
                    "Date": date_
                })
                print(f"Processed email from {from_} with subject: {subject}")

        # Create a DataFrame
        df = pd.DataFrame(job_data)

        # Add placeholder columns for additional information
        df["Company"] = ""
        df["Position"] = ""
        df["Status"] = ""
        df["Notes"] = ""

        # Save the data to an Excel file
        excel_filename = "job_tracker.xlsx"

        # Create a new Excel file with a worksheet
        df.to_excel(excel_filename, index=False)
        print(f"Job tracker saved to {excel_filename}")

    except HttpError as error:
        print(f"An error occurred: {error}")

if __name__ == '__main__':
    main()
# Out:
# Loaded credentials from token.json
# Messages:
# Processed email from Google Developer Program <googledev-noreply@google.com> with subject: Welcome to the Google Developer Program
# Processed email from Google <no-reply@accounts.google.com> with subject: Security alert
# Processed email from no-reply@optimove.com with subject: Thank you for applying to Optimove
# Processed email from urban@myworkday.com with subject: Your application has been received
# Processed email from urban@myworkday.com with subject: Verify your candidate account
# Processed email from TikTok <noreply@careers.tiktok.com> with subject: Thank you for applying to TikTok!
# Processed email from LinkedIn <jobs-noreply@linkedin.com> with subject: Arya, your application was sent to Degas
# Processed email from Arya Amarnath <realyx.arya@gmail.com> with subject: Re: Help with TS-SCI Clearance
# Processed email from David Kasten <dlkasten@gmail.com> with subject: Re: Help with TS-SCI Clearance
# Processed email from Dice <dice@connect.dice.com> with subject: Exciting job openings at Kroger with relocation provided!
# Processed email from FlutterFlow <noreply@flutterflow.io> with subject: How's Your FlutterFlow Journey Going? —  A Message from FlutterFlow's CEO
# Processed email from LinkedIn <jobs-noreply@linkedin.com> with subject: Arya, your application was sent to techolution
# Processed email from Caitlin at Alignable <membersuccess@alignable.com> with subject: Arya, people in Fort Collins want to know what services you provide!
# Processed email from Backdrop Build <no-reply@backdropbuild.com> with subject: Your Backdrop Build Application Has Been Approved!
# Processed email from Adobe <message@adobe.com> with subject: Verification code
# Processed email from Kody <noreply@candidates.workablemail.com> with subject: Data Analyst - Kody
# Processed email from John Cristos <john.cristos@outlier.ai> with subject: Outlier: Coders Onboarding Next Steps
# Processed email from "Viasat, Inc. @ icims" <viasat+autoreply@talent.icims.com> with subject: Thank you for applying at Viasat, Inc.
# Processed email from no-reply@outlier.ai with subject: Your Application Has Been Received!
# Processed email from Workday HRHPI <hp@myworkday.com> with subject: Thank you - we've received your job application
# Processed email from Arya Amarnath <realyx.arya@gmail.com> with subject: Help with TS-SCI Clearance
# Processed email from Indeed <no-reply@indeed.com> with subject: Your account is confirmed. What's next?
# Processed email from Alignable <membersuccess@alignable.com> with subject: Want the secret to growing your business on Alignable?
# Processed email from Fort Collins on Alignable <membersuccess@alignable.com> with subject: A new business you should meet
# Processed email from David Fano <david.fano@hello.tealhq.com> with subject: How to get an interview
# Processed email from Suggested Connections <membersuccess@alignable.com> with subject: Masten Solutions
# Processed email from Arya Amarnath <realyx.arya@gmail.com> with subject: Re: Your Other project on GitHub
# Processed email from Backdrop Build <no-reply@backdropbuild.com> with subject: Activate your Build account
# Processed email from Colepepper Plumbing <colepepper@colepepperplumbing.com> with subject: It's Time For Your Annual Water Heater Flush
# Processed email from Adobe <message@adobe.com> with subject: Verification code
# Processed email from FlutterFlow <noreply@flutterflow.io> with subject: Top Tips & Best Practices from FlutterFlow University 🧑‍🎓
# Processed email from Joey DeBruin <joeydebruin@backdropbuild.app> with subject: RE: Your Other project on GitHub
# Processed email from Amazon Web Services <aws-marketing-email-replies@amazon.com> with subject: Don’t miss out! Last chance to register for live keynote on generative AI from AWS.
# Processed email from Jobot <alerts@jobs.jobot.com> with subject: Instant Interview: Your Application for Machine Learning - Software Engineer
# Processed email from LinkedIn <jobs-noreply@linkedin.com> with subject: Arya, your application was sent to Insight Global
# Processed email from LinkedIn <jobs-noreply@linkedin.com> with subject: Arya, your application was sent to Murphy & Associates, Inc.
# Processed email from LinkedIn <jobs-noreply@linkedin.com> with subject: Arya, your application was sent to Anunta
# Processed email from LinkedIn <jobs-noreply@linkedin.com> with subject: Arya, your application was sent to Jobot
# Processed email from LinkedIn <jobs-noreply@linkedin.com> with subject: Arya, your application was sent to Squirrel Ai Learning
# Processed email from LinkedIn <jobs-noreply@linkedin.com> with subject: Arya, your application was sent to AVNIK Defense Solutions, Inc.
# Processed email from no-reply@us.greenhouse-mail.io with subject: Thank you for applying to GSW Sports, LLC
# Processed email from LinkedIn <jobs-noreply@linkedin.com> with subject: Arya, your application was sent to Golden State Warriors
# Processed email from LinkedIn <jobs-noreply@linkedin.com> with subject: Arya, your application was sent to BBC Research & Consulting
# Processed email from hiringthebest@knowbe4.com with subject: Thank You for Your Application
# Processed email from LinkedIn <jobs-noreply@linkedin.com> with subject: Arya, your application was sent to KnowBe4
# Processed email from Fort Collins Local Spark <newsletter@alignable.com> with subject: Arya, wondering where to start? We’ve got you.
# Processed email from New Profile Activity <membersuccess@alignable.com> with subject: 17 people just checked out Realyx LLC - see who!
# Processed email from FlutterFlow <noreply@flutterflow.io> with subject: Connect Your FlutterFlow App to a Database in 3️ Simple Steps
# Processed email from Dice <dice@connect.dice.com> with subject: The Future is Intelligent: Tech Jobs Transformed by AI and Machine Learning
# Processed email from Tracy at Alignable <membersuccess@alignable.com> with subject: Want to grow your network faster?
# Processed email from Tracy at Alignable <membersuccess@alignable.com> with subject: Ready to get noticed?
# Processed email from paramountcareers@noreply.jobs2web.com with subject: New jobs posted from Paramount
# Processed email from FlutterFlow <noreply@flutterflow.io> with subject: Unlock the Power of FlutterFlow – Your Step-by-Step Guide
# Processed email from Adobe <message@adobe.com> with subject: Your Adobe ID password has changed
# Processed email from Dice <dice@connect.dice.com> with subject: The Future is Intelligent: Tech Jobs Transformed by AI and Machine Learning
# Processed email from Aparna via Alignable <support@alignable.com> with subject: Private Message from Zoho Books
# Processed email from Tracy at Alignable <membersuccess@alignable.com> with subject: Meet like-minded people, Arya
# Processed email from GitHub <noreply@github.com> with subject: [GitHub] A third-party OAuth application has been added to your account
# Processed email from Casa Bonita <shop@casabonitadenver.com> with subject: We've Got Something For The Whole Casa
# Processed email from Zillow Rental Manager <noreply@comet.zillow.com> with subject: Rental market update for 9539 E Arbor Pl
# Processed email from FlutterFlow <noreply@flutterflow.io> with subject: Welcome to FlutterFlow – Unlock Your App Development Potential 🚀
# Processed email from FlutterFlow <team@flutterflow.io> with subject: Welcome to FlutterFlow - Resources to get started
# Processed email from The Google Account Team <google-noreply@google.com> with subject: Arya, review your Google Account settings
# Processed email from Google <no-reply@accounts.google.com> with subject: Security alert
# Processed email from Google <no-reply@accounts.google.com> with subject: Security alert
# Processed email from Amazon Web Services <aws-marketing-email-replies@amazon.com> with subject: Watch live: Learn about new advancements in generative AI at AWS
# Processed email from Recommendations via Alignable <membersuccess@alignable.com> with subject: Aparna at Zoho Books
# Processed email from Tracy at Alignable <membersuccess@alignable.com> with subject: You've sent your first connection request, Arya!
# Processed email from Aparna <membersuccess@alignable.com> with subject: Say hi!
# Processed email from LinkedIn <jobs-noreply@linkedin.com> with subject: Arya, your application was sent to MediaTek Inc.
# Processed email from Alignable <noreply@email.alignable.com> with subject: Reset password instructions
# Processed email from Google <no-reply@accounts.google.com> with subject: Security alert
# Processed email from Joey DeBruin <joeydebruin@backdropbuild.app> with subject: Your Other project on GitHub
# Processed email from David Fano <david.fano@hello.tealhq.com> with subject: #1 job search tip
# Processed email from "BEON.tech" <hello@beon.tech> with subject: LatAm Dev Insider | AI Hacks, Transformative Reads & Communication Mastery 🚀
# Processed email from Amazon Web Services <aws-marketing-email-replies@amazon.com> with subject: Technical deep dives on Twitch
# Processed email from The Home Depot <HomeDepot@order.homedepot.com> with subject: Hi Donnin, your Home Depot receipt for # H1512-298469 is here
# Processed email from Dice <dice@connect.dice.com> with subject: Get the most relevant jobs sent to you when you want them!
# Processed email from Dice <dice@connect.dice.com> with subject: Top AI Certifications to Get You Ahead in Your Tech Career
# Processed email from paramountcareers@noreply.jobs2web.com with subject: New jobs posted from Paramount
# Processed email from Dice <dice@connect.dice.com> with subject: Be among the first applicants to be contacted for Junior Data Scientist jobs!
# Processed email from Dice <dice@connect.dice.com> with subject: Top AI Certifications to Get You Ahead in Your Tech Career
# Processed email from Toyon <do-not-reply@mail.paylocity.com> with subject: Thank you for your interest
# Processed email from Arya Amarnath <realyx.arya@gmail.com> with subject: Fwd: Home Depot Kitchen Design-Fishhawk
# Processed email from David Fano <david.fano@hello.tealhq.com> with subject: Apply faster
# Processed email from Amazon Web Services <aws-marketing-email-replies@amazon.com> with subject: Tell us which topics interest you most
# Processed email from Dice <dice@connect.dice.com> with subject: Charting AI Tech Career Pathways: Navigating From Entry to Senior Level
# Processed email from paramountcareers@noreply.jobs2web.com with subject: New jobs posted from Paramount
# Processed email from Dice <dice@connect.dice.com> with subject: Charting AI Tech Career Pathways: Navigating From Entry to Senior Level
# Processed email from Dice <dice@connect.dice.com> with subject: Please tell us about your experience
# Processed email from no-reply@loopcv.com with subject: [Action required] You have a new message from a company
# Processed email from Dice <dice@connect.dice.com> with subject: Restart your job search with Dice.
# Processed email from Donnin R <donnin.ar@gmail.com> with subject: Fwd: Home Depot Kitchen Design-Fishhawk
# Processed email from no-reply@loopcv.com with subject: [Action required] You have a new message from a company
# Processed email from Shobhit Sharma <shobhit@synergisticit.com> with subject: Full-Time Job Placement Program - $75,000-$150,000 P.A. - OPT/CPT/GC/PR/H4/L2/CITIZEN's - Remote Program
# Processed email from Unlearn Talent Team <no-reply@ashbyhq.com> with subject: Regarding your application at Unlearn
# Processed email from no-reply@loopcv.com with subject: [Action required] You have a new message from a company
# Processed email from Jennifer Rawson <jennifer.rawson@geniussports.com> with subject: Important update about your application to Second Spectrum
# Processed email from David Fano <david.fano@hello.tealhq.com> with subject: Rejected?
# Processed email from LoopCV LTD <invoice+statements@loopcv.com> with subject: Your receipt from LoopCV LTD #2610-5774
# Job tracker saved to job_tracker.xlsx

# %%
# function to extract job info from email
def extract_job_info(subject, body):
    company = None
    role_title = None
    salary_rate = None
    link_to_job_advert = None
    application_date = None
    contact_name = None
    contact_email = None
    contact_tel = None

    doc = nlp(body)

    # extract entities using NLP
    for ent in doc.ents:
        if ent.label_ == 'ORG':
            company = ent.text
        elif ent.label_ == 'MONEY':
            salary_rate = ent.text
        elif ent.label_ in ('DATE', 'TIME'):
            application_date = ent.text
        elif ent.label_ == 'PERSON':
            contact_name = ent.text

    # fallback extraction using regex
    if not company:
        company_match = re.search(r'Company: (.+)', body)
        if company_match:
            company = company_match.group(1)
    if not role_title:
        role_title_match = re.search(r'Position: (.+)', body)
        if role_title_match:
            role_title = role_title_match.group(1)
    if not salary_rate:
        salary_rate_match = re.search(r'Salary: (.+)', body)
        if salary_rate_match:
            salary_rate = salary_rate_match.group(1)
    if not link_to_job_advert:
        link_to_job_advert_match = re.search(r'Link: (http.+)', body)
        if link_to_job_advert_match:
            link_to_job_advert = link_to_job_advert_match.group(1)
    if not application_date:
        application_date_match = re.search(r'Date: (\d{2}/\d{2}/\d{2})', body)
        if application_date_match:
            application_date = application_date_match.group(1)
    if not contact_name or not contact_email or not contact_tel:
        contact_match = re.search(r'Contact: (.+)', body)
        if contact_match:
            contact_info = contact_match.group(1).split(' - ')
            if len(contact_info) >= 3:
                contact_name, contact_email, contact_tel = contact_info[:3]

    return {
        "Company": company,
        "Role Title": role_title,
        "Salary/Rate": salary_rate,
        "Link to Job Advert": link_to_job_advert,
        "Application Date": application_date,
        "Contact Name": contact_name,
        "Contact Email": contact_email,
        "Contact Tel": contact_tel
    }

# function to get the body of the email
def get_body(payload):
    body = ""
    if 'parts' in payload:
        for part in payload['parts']:
            if part['mimeType'] == 'text/plain':
                body += base64.urlsafe_b64decode(part['body']['data']).decode('utf-8')
            elif part['mimeType'] == 'text/html':
                body += BeautifulSoup(base64.urlsafe_b64decode(part['body']['data']), 'html.parser').get_text()
    else:
        body = base64.urlsafe_b64decode(payload['body']['data']).decode('utf-8')
    return body

# main function to fetch and process emails
def main():
    creds = None
    # load credentials
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
        print("loaded credentials from token.json")
    else:
        print("token.json not found, need to authenticate")
    
    # refresh or get new credentials if necessary
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            try:
                creds.refresh(Request())
                print("credentials refreshed")
            except Exception as e:
                print(f"failed to refresh credentials: {e}")
        else:
            try:
                flow = InstalledAppFlow.from_client_secrets_file('credentials.json', SCOPES)
                creds = flow.run_local_server(port=0)
                print("credentials obtained from flow")
            except Exception as e:
                print(f"failed to obtain credentials: {e}")
                return
        # save credentials
        with open('token.json', 'w') as token:
            token.write(creds.to_json())
            print("credentials saved to token.json")

    try:
        # call the Gmail API
        service = build('gmail', 'v1', credentials=creds)

        # get list of messages with specific keywords from the last 5 months
        query = 'subject:(job application OR applied OR application received)'
        results = service.users().messages().list(userId='me', q=query).execute()
        messages = results.get('messages', [])

        job_data = []

        if not messages:
            print('no messages found')
        else:
            print('messages:')
            for message in messages:
                msg = service.users().messages().get(userId='me', id=message['id']).execute()
                payload = msg['payload']
                headers = payload.get('headers')
                subject = None
                for header in headers:
                    if header['name'] == 'Subject':
                        subject = header['value']
                body = get_body(payload)
                job_info = extract_job_info(subject, body)
                job_data.append(job_info)
                print(f"processed email with subject: {subject}")

        # create a DataFrame
        df = pd.DataFrame(job_data)

        # add placeholder columns for additional information
        df["Company"] = df["Company"].fillna("")
        df["Role Title"] = df["Role Title"].fillna("")
        df["Salary/Rate"] = df["Salary/Rate"].fillna("")
        df["Link to Job Advert"] = df["Link to Job Advert"].fillna("")
        df["Application Date"] = df["Application Date"].fillna("")
        df["Contact Name"] = df["Contact Name"].fillna("")
        df["Contact Email"] = df["Contact Email"].fillna("")
        df["Contact Tel"] = df["Contact Tel"].fillna("")

        # save the data to an Excel file
        excel_filename = "job_tracker_v2.xlsx"

        # create a new Excel file with a worksheet
        df.to_excel(excel_filename, index=False)
        print(f"job tracker saved to {excel_filename}")

    except HttpError as error:
        print(f"an error occurred: {error}")

if __name__ == '__main__':
    main()
# Out:
# loaded credentials from token.json
# messages:
# processed email with subject: Thank you - we've received your job application
# job tracker saved to job_tracker_v2.xlsx
